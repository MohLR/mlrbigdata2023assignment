# %% [markdown]
# Implementing Map Reduce in Google Colab

# %%
# Import the required libraries
import sys
from itertools import groupby

# %%
# Create a map function
def mapfunc(w):
    # Let us remove all puncuation and spaces.  
    cleanword = ''.join([i for i in w if i.isalpha()])
    return [cleanword,1]

# %%
# Create a reduce function
def reducefunc(key, values):
    counts = [x[1] for x in values]
    return [key,sum(counts)]

# %%
# Download the data
# !wget https://gutenberg.org/cache/epub/25883/pg25883.txt -O humptydumpty.txt
# Out:
# --2023-02-23 21:33:40--  https://gutenberg.org/cache/epub/25883/pg25883.txt
# Resolving gutenberg.org (gutenberg.org)... 152.19.134.47, 2610:28:3090:3000:0:bad:cafe:47
# Connecting to gutenberg.org (gutenberg.org)|152.19.134.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 26396 (26K) [text/plain]
# Saving to: ‘humptydumpty.txt’
#
# humptydumpty.txt    100%[===================>]  25.78K  --.-KB/s    in 0s
#
# 2023-02-23 21:33:41 (234 MB/s) - ‘humptydumpty.txt’ saved [26396/26396]

# %%
# Split the document into single word
with open("humptydumpty.txt") as f:
    words=[word for line in f for word in line.split()]

# %%
print(words)
# Out:
# ['\ufeffProject', "Gutenberg's", "Denslow's", 'Humpty', 'Dumpty,', 'by', 'William', 'Wallace', 'Denslow', 'This', 'eBook', 'is', 'for', 'the', 'use', 'of', 'anyone', 'anywhere', 'at', 'no', 'cost', 'and', 'with', 'almost', 'no', 'restrictions', 'whatsoever.', 'You', 'may', 'copy', 'it,', 'give', 'it', 'away', 'or', 're-use', 'it', 'under', 'the', 'terms', 'of', 'the', 'Project', 'Gutenberg', 'License', 'included', 'with', 'this', 'eBook', 'or', 'online', 'at', 'www.gutenberg.org', 'Title:', "Denslow's", 'Humpty', 'Dumpty', 'Author:', 'William', 'Wallace', 'Denslow', 'Release', 'Date:', 'June', '23,', '2008', '[EBook', '#25883]', 'Language:', 'English', '***', 'START', 'OF', 'THIS', 'PROJECT', 'GUTENBERG', 'EBOOK', "DENSLOW'S", 'HUMPTY', 'DUMPTY', '***', 'Produced', 'by', 'Louise', 'Hope,', 'David', 'Edwards', 'and', 'the', 'Online', 'Distributed', 'Proofreading', 'Team', 'at', 'http://www.pgdp.net', '(This', 'book', 'was', 'produced', 'from', 'scanned', 'images', 'of', 'public', 'dom
# ...

# %%
map_result = [*map(mapfunc, words)]
print(map_result)
# Out:
# [['Project', 1], ['Gutenbergs', 1], ['Denslows', 1], ['Humpty', 1], ['Dumpty', 1], ['by', 1], ['William', 1], ['Wallace', 1], ['Denslow', 1], ['This', 1], ['eBook', 1], ['is', 1], ['for', 1], ['the', 1], ['use', 1], ['of', 1], ['anyone', 1], ['anywhere', 1], ['at', 1], ['no', 1], ['cost', 1], ['and', 1], ['with', 1], ['almost', 1], ['no', 1], ['restrictions', 1], ['whatsoever', 1], ['You', 1], ['may', 1], ['copy', 1], ['it', 1], ['give', 1], ['it', 1], ['away', 1], ['or', 1], ['reuse', 1], ['it', 1], ['under', 1], ['the', 1], ['terms', 1], ['of', 1], ['the', 1], ['Project', 1], ['Gutenberg', 1], ['License', 1], ['included', 1], ['with', 1], ['this', 1], ['eBook', 1], ['or', 1], ['online', 1], ['at', 1], ['wwwgutenbergorg', 1], ['Title', 1], ['Denslows', 1], ['Humpty', 1], ['Dumpty', 1], ['Author', 1], ['William', 1], ['Wallace', 1], ['Denslow', 1], ['Release', 1], ['Date', 1], ['June', 1], ['', 1], ['', 1], ['EBook', 1], ['', 1], ['Language', 1], ['English', 1], ['', 1], ['START', 1]
# ...

# %%
# Sort the map_result into alphabetical order
map_result_sorted = sorted (map_result, key = lambda x: x[0])

# %%
# Combine/Reduce the map_result_sorted
reduce_result = []
for k, g in groupby(map_result_sorted, key = lambda x: x[0]):
    reduce_result.append(reducefunc(k, list(g)))

# %%
print(reduce_result)
# Out:
# [['', 69], ['A', 2], ['ABC', 1], ['ACTUAL', 1], ['AGREE', 2], ['AGREEMENT', 1], ['AK', 1], ['AND', 1], ['ANY', 3], ['ANYTHING', 1], ['ASCII', 2], ['ASIS', 1], ['About', 1], ['Adapted', 1], ['Additional', 1], ['All', 1], ['Any', 1], ['Archive', 13], ['August', 1], ['Author', 1], ['B', 2], ['BE', 1], ['BEFORE', 1], ['BREACH', 2], ['BUT', 1], ['Bare', 1], ['BeanStalk', 1], ['Bears', 1], ['Black', 2], ['Book', 1], ['Books', 1], ['Brief', 1], ['Built', 1], ['But', 1], ['By', 1], ['C', 2], ['CONSEQUENTIAL', 1], ['CONTRACT', 1], ['COPYRIGHT', 1], ['Cannot', 1], ['Cents', 2], ['Chief', 1], ['Children', 1], ['Circus', 1], ['City', 1], ['Co', 1], ['Company', 1], ['Compliance', 1], ['Contact', 1], ['Contributions', 1], ['Copyright', 2], ['Countries', 1], ['Creating', 1], ['D', 1], ['DAMAGE', 1], ['DAMAGES', 2], ['DENSLOW', 1], ['DENSLOWS', 2], ['DIRECT', 1], ['DISCLAIMER', 1], ['DISTRIBUTE', 1], ['DISTRIBUTOR', 1], ['DONATIONS', 1], ['DUMPTY', 4], ['Date', 1], ['David', 2], ['Decorated', 1], ['
# ...
