# %%
# Install pyspark
# !pip install pyspark
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyspark
#   Downloading pyspark-3.4.0.tar.gz (310.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.8/310.8 MB 3.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.9/dist-packages (from pyspark) (0.10.9.7)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.4.0-py2.py3-none-any.whl size=311317145 sha256=7b92c42a9e21064a10560c459cc906b40db0fd997690b647861962a66e03e05f
#   Stored in directory: /root/.cache/pip/wheels/9f/34/a4/159aa12d0a510d5ff7c8f0220abbea42e5d81ecf588c4fd884
# Successfully built pyspark
# Installing collected packages: pyspark
# Successfully installed pyspark-3.4.0

# %%
# Import Apache Spark SQL
from pyspark.sql import SparkSession

# Create Spark Session/Context
# We are using local machine with all the CPU cores [*]
spark = SparkSession.builder \
    .master("local[*]") \
    .appName("Hello Pyspark") \
    .config("spark.some.config.option", "some-value") \
    .getOrCreate()

# %%
# Check spark session
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://511b9b635b49:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.4.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Hello Pyspark</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# Mounting google drive so we can access any file inside it
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Reading a csv file with a semicolon(;) delimiter
import pandas as pd
data = pd.read_csv('/content/gdrive/My Drive/market-basket.csv', sep=";")
data.head()
# Out:
# <ipython-input-5-842ab7b5f3e3>:3: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('/content/gdrive/My Drive/market-basket.csv', sep=";")
#    BillNo                             Itemname  Quantity              Date  \
# 0  536365   WHITE HANGING HEART T-LIGHT HOLDER         6  01.12.2010 08:26
# 1  536365                  WHITE METAL LANTERN         6  01.12.2010 08:26
# 2  536365       CREAM CUPID HEARTS COAT HANGER         8  01.12.2010 08:26
# 3  536365  KNITTED UNION FLAG HOT WATER BOTTLE         6  01.12.2010 08:26
# 4  536365       RED WOOLLY HOTTIE WHITE HEART.         6  01.12.2010 08:26
#
#   Price  CustomerID         Country
# 0  2,55     17850.0  United Kingdom
# 1  3,39     17850.0  United Kingdom
# 2  2,75     17850.0  United Kingdom
# 3  3,39     17850.0  United Kingdom
# 4  3,39     17850.0  United Kingdom

# %%
from pyspark.sql import functions as F

sparkdata = spark.createDataFrame(data) # Create a dataframe
basketdata = sparkdata.dropDuplicates(['BillNo', 'Itemname']).sort('BillNo') # Drop any duplicates BillNo and Itemname, then sort the dataframe according to BillNo
basketdata = basketdata.groupBy("BillNo").agg(F.collect_list("Itemname")).sort('BillNo') # Group the items with the same BillNo and then sort them according to BillNo

# %%
from pyspark.ml.fpm import FPGrowth

#Frequent Pattern Growth – FP Growth is a method of mining frequent itemsets
fpGrowth = FPGrowth(itemsCol="collect_list(Itemname)", minSupport=0.06, minConfidence=0.06) 
model = fpGrowth.fit(basketdata)

# Display frequent itemsets.
model.freqItemsets.show()
# Out:
# +--------------------+----+
# |               items|freq|
# +--------------------+----+
# |[REGENCY CAKESTAN...|1904|
# |[LUNCH BAG RED RE...|1541|
# |[WHITE HANGING HE...|2202|
# |[ASSORTED COLOUR ...|1431|
# |               [NaN]|1455|
# |[SET OF 3 CAKE TI...|1346|
# |[JUMBO BAG RED RE...|2064|
# |     [PARTY BUNTING]|1656|
# +--------------------+----+

# %%
frequent_itemsets = model.freqItemsets.select("*").toPandas() # changing the frequent itemsets dataframe into Pandas
frequent_itemsets.to_excel('market_basket_frequent_itemsets.xlsx') # saving the Pandas frequent itemsets into excel

# %%
# Display generated association rules.
model.associationRules.show()
# Out:
# +----------+----------+----------+----+-------+
# |antecedent|consequent|confidence|lift|support|
# +----------+----------+----------+----+-------+
# +----------+----------+----------+----+-------+

# %%
rules = model.associationRules.select("*").toPandas()
rules.to_excel('market_basket_rules.xlsx')

# %%
# Initializing different minSupport and minConfidence
minSupp = [0.01, 0.03, 0.05, 0.07, 0.1] 
minConfi = [0.01, 0.03, 0.05, 0.07, 0.1]

#Frequent Pattern Growth – FP Growth is a method of mining frequent itemsets with a looping
for minConf in minConfi:
  for minSup in minSupp: 
    fpGrowth = FPGrowth(itemsCol="collect_list(Itemname)", minSupport=minSup, minConfidence=minConf) 
    model = fpGrowth.fit(basketdata)

    # Display association rules.
    print("associatiobn rules for frequent itemsets with minSupport=" + str(minSup) + " and minConfidence=" + str(minConf) +"\n")
    model.associationRules.show()
# Out:
# associatiobn rules for frequent itemsets with minSupport=0.01 and minConfidence=0.01
#
# +--------------------+--------------------+-------------------+------------------+--------------------+
#

# +--------------------+--------------------+-------------------+------------------+--------------------+
# only showing top 20 rows
#
# associatiobn rules for frequent itemsets with minSupport=0.03 and minConfidence=0.03
#
# +--------------------+--------------------+-------------------+-----------------+--------------------+
# |          antecedent|          consequent|         confidence|             lift|             support|
# +--------------------+--------------------+-------------------+-----------------+--------------------+
# |[JUMBO STORAGE BA...|[JUMBO BAG RED RE...| 0.6120543293718166|6.423901616851581|  0.0332825555093939|
# |[GREEN REGENCY TE...|[ROSES REGENCY TE...| 0.7497435897435898|16.03326296605665|0.033744172090661495|
# |[ROSES REGENCY TE...|[GREEN REGENCY TE...|  0.721618953603159|16.03326296605665|0.033744172090661495|
# |[JUMBO BAG PINK P...|[JUMBO BAG RED RE...| 0.6763005780346821|7.098207084285523|0.037806398005816366|
# |[JUMBO BAG RED RE...|[JUMBO SHOPPER VI...|0.32751937984496127|6.084950536519208|  0.0312052808936897|
# |[JUMBO BAG RED RE...|[JUMBO BAG PINK P...|0.39680232558139533|7.098207084285522|0.037806398005816366|
# |[JUMBO BAG RED RE...|[JUMBO STORAGE BA...| 0.3493217054263566|6.423901616851581|  0.0332825555093939|
# |[JUMBO SHOPPER VI...|[JUMBO BAG RED RE...| 0.5797598627787307|6.084950536519207|  0.0312052808936897|
# +--------------------+--------------------+-------------------+-----------------+--------------------+
#
# associatiobn rules for frequent itemsets with minSupport=0.05 and minConfidence=0.03
#
# +----------+----------+----------+----+-------+
# |antecedent|consequent|confidence|lift|support|
# +----------+----------+----------+----+-------+
# +----------+----------+----------+----+-------+
#
# associatiobn rules for frequent itemsets with minSupport=0.07 and minConfidence=0.03
#
# +----------+----------+----------+----+-------+
# |antecedent|consequent|confidence|lift|support|
# +----------+----------+----------+----+-------+
# +----------+----------+----------+----+-------+
#
# associatiobn rules for frequent itemsets with minSupport=0.1 and minConfidence=0.03
#
# +----------+----------+----------+----+-------+
# |antecedent|consequent|confidence|lift|support|
# +----------+----------+----------+----+-------+
# +----------+----------+----------+----+-------+
#
# associatiobn rules for frequent itemsets with minSupport=0.01 and minConfidence=0.05
#
# +--------------------+--------------------+-------------------+------------------+--------------------+
# |          antecedent|          consequent|         confidence|              lift|             support|
# +--------------------+--------------------+-------------------+------------------+--------------------+
# |[JUMBO BAG ALPHAB...|  [JUMBO BAG APPLES]| 0.5669099756690997|12.739596268588908| 0.01075566634353506|
# |[SET OF 6 SPICE T...|[RECIPE BOX PANTR...| 0.2952029520295203|5.8939922118115184| 0.01107879795042238|
# |[SET OF 6 SPICE T...|[SET OF 3 CAKE TI...| 0.4944649446494465| 7.958093681976939|0.018556986566957485|
# |[SET OF 6 SPICE T...|[JAM MAKING SET P...|0.26691266912669126| 5.181119311193112|  0.0100170798135069|
# |[SET OF 6 SPICE T...|[JAM MAKING SET W...|0.31857318573185733| 6.337236843442815|0.011955869454830818|
# |[PICNIC BASKET WI...|    [DOTCOM POSTAGE]|                0.5|15.298728813559322| 0.01052485805290126|
# |[RED  HARMONICA I...|[BLUE HARMONICA I...|            0.48125|17.851573202054794|0.014217790703042053|
# |[LUNCH BAG APPLE ...|[LUNCH BAG SUKI D...| 0.6447688564476886|12.956983058651463|0.012232839403591376|
# |[LUNCH BAG APPLE ...|[LUNCH BAG CARS B...| 0.5352798053527981|10.243609914626912|0.010155564787887181|
# |[LUNCH BAG APPLE ...|[LUNCH BAG RED RE...| 0.6545012165450121| 9.200817556141855|0.012417486036098416|
# |[LUNCH BAG APPLE ...|[LUNCH BAG SPACEB...|  0.559610705596107| 10.56917760708672| 0.01061718136915478|
# |[ALARM CLOCK BAKE...|[ALARM CLOCK BAKE...|0.35071090047393366|18.219305124620682|0.010247888104140701|
# |[ALARM CLOCK BAKE...|[ALARM CLOCK BAKE...| 0.4834123222748815|13.797313751568852|0.014125467386788533|
# |[ALARM CLOCK BAKE...|[ALARM CLOCK BAKE...| 0.4060031595576619|15.677801150619661|0.011863546138577298|
# |[LUNCH BAG PINK P...|[LUNCH BAG WOODLAND]|0.47217537942664417|10.187983311274296|0.012925264275492775|
# |[LUNCH BAG PINK P...|[LUNCH BAG SUKI D...| 0.4924114671163575|  9.89527793334105|0.013479204173013895|
# |[LUNCH BAG PINK P...|[LUNCH BAG CARS B...| 0.5328836424957841|10.197754723839374|0.014587083968056132|
# |[LUNCH BAG PINK P...|[JUMBO BAG RED RE...| 0.3827993254637437| 4.017723734264089|  0.0104786963947745|
# |[LUNCH BAG PINK P...|[LUNCH BAG  BLACK...|  0.596964586846543|10.263526860997349| 0.01634122697687301|
# |[LUNCH BAG PINK P...|[LUNCH BAG SPACEB...| 0.4839797639123103| 9.140761661405735|0.013248395882380096|
# +--------------------+--------------------+-------------------+------------------+--------------------+
# only showing top 20 rows
#
# associatiobn rules for frequent itemsets with minSupport=0.03 and minConfidence=0.05
#
# +--------------------+--------------------+-------------------+-----------------+--------------------+
# |          antecedent|          consequent|         confidence|             lift|             support|
# +--------------------+--------------------+-------------------+-----------------+--------------------+
# |[JUMBO STORAGE BA...|[JUMBO BAG RED RE...| 0.6120543293718166|6.423901616851581|  0.0332825555093939|
# |[GREEN REGENCY TE...|[ROSES REGENCY TE...| 0.7497435897435898|16.03326296605665|0.033744172090661495|
# |[ROSES REGENCY TE...|[GREEN REGENCY TE...|  0.721618953603159|16.03326296605665|0.033744172090661495|
# |[JUMBO BAG PINK P...|[JUMBO BAG RED RE...| 0.6763005780346821|7.098207084285523|0.037806398005816366|
# |[JUMBO BAG RED RE...|[JUMBO SHOPPER VI...|0.32751937984496127|6.084950536519208|  0.0312052808936897|
# |[JUMBO BAG RED RE...|[JUMBO BAG PINK P...|0.39680232558139533|7.098207084285522|0.037806398005816366|
# |[JUMBO BAG RED RE...|[JUMBO STORAGE BA...| 0.3493217054263566|6.423901616851581|  0.0332825555093939|
# |[JUMBO SHOPPER VI...|[JUMBO BAG RED RE...| 0.5797598627787307|6.084950536519207|  0.0312052808936897|
# +--------------------+--------------------+-------------------+-----------------+--------------------+
#
# associatiobn rules for frequent itemsets with minSupport=0.05 and minConfidence=0.05
#
# +----------+----------+----------+----+-------+
# |antecedent|consequent|confidence|lift|support|
# +----------+----------+----------+----+-------+
# +----------+----------+----------+----+-------+
#
# associatiobn rules for frequent itemsets with minSupport=0.07 and minConfidence=0.05
#
# +----------+----------+----------+----+-------+
# |antecedent|consequent|confidence|lift|support|
# +----------+----------+----------+----+-------+
# +----------+----------+----------+----+-------+
#
# associatiobn rules for frequent itemsets with minSupport=0.1 and minConfidence=0.05
#
# +----------+----------+----------+----+-------+
# |antecedent|consequent|confidence|lift|support|
# +----------+----------+----------+----+-------+
# +----------+----------+----------+----+-------+
#
# associatiobn rules for frequent itemsets with minSupport=0.01 and minConfidence=0.07
#
# +--------------------+--------------------+-------------------+------------------+--------------------+
# |          antecedent|          consequent|         confidence|              lift|             support|
# +--------------------+--------------------+-------------------+------------------+--------------------+
# |[JUMBO BAG ALPHAB...|  [JUMBO BAG APPLES]| 0.5669099756690997|12.739596268588908| 0.01075566634353506|
# |[SET OF 6 SPICE T...|[RECIPE BOX PANTR...| 0.2952029520295203|5.8939922118115184| 0.01107879795042238|
# |[SET OF 6 SPICE T...|[SET OF 3 CAKE TI...| 0.4944649446494465| 7.958093681976939|0.018556986566957485|
# |[SET OF 6 SPICE T...|[JAM MAKING SET P...|0.26691266912669126| 5.181119311193112|  0.0100170798135069|
# |[SET OF 6 SPICE T...|[JAM MAKING SET W...|0.31857318573185733| 6.337236843442815|0.011955869454830818|
# |[PICNIC BASKET WI...|    [DOTCOM POSTAGE]|                0.5|15.298728813559322| 0.01052485805290126|
# |[RED  HARMONICA I...|[BLUE HARMONICA I...|            0.48125|17.851573202054794|0.014217790703042053|
# |[LUNCH BAG APPLE ...|[LUNCH BAG SUKI D...| 0.6447688564476886|12.956983058651463|0.012232839403591376|
# |[LUNCH BAG APPLE ...|[LUNCH BAG CARS B...| 0.5352798053527981|10.243609914626912|0.010155564787887181|
# |[LUNCH BAG APPLE ...|[LUNCH BAG RED RE...| 0.6545012165450121| 9.200817556141855|0.012417486036098416|
# |[LUNCH BAG APPLE ...|[LUNCH BAG SPACEB...|  0.559610705596107| 10.56917760708672| 0.01061718136915478|
# |[ALARM CLOCK BAKE...|[ALARM CLOCK BAKE...|0.35071090047393366|18.219305124620682|0.010247888104140701|
# |[ALARM CLOCK BAKE...|[ALARM CLOCK BAKE...| 0.4834123222748815|13.797313751568852|0.014125467386788533|
# |[ALARM CLOCK BAKE...|[ALARM CLOCK BAKE...| 0.4060031595576619|15.677801150619661|0.011863546138577298|
# |[LUNCH BAG PINK P...|[LUNCH BAG WOODLAND]|0.47217537942664417|10.187983311274296|0.012925264275492775|
# |[LUNCH BAG PINK P...|[LUNCH BAG SUKI D...| 0.4924114671163575|  9.89527793334105|0.013479204173013895|
# |[LUNCH BAG PINK P...|[LUNCH BAG CARS B...| 0.5328836424957841|10.197754723839374|0.014587083968056132|
# |[LUNCH BAG PINK P...|[JUMBO BAG RED RE...| 0.3827993254637437| 4.017723734264089|  0.0104786963947745|
# |[LUNCH BAG PINK P...|[LUNCH BAG  BLACK...|  0.596964586846543|10.263526860997349| 0.01634122697687301|
# |[LUNCH BAG PINK P...|[LUNCH BAG SPACEB...| 0.4839797639123103| 9.140761661405735|0.013248395882380096|
# +--------------------+--------------------+-------------------+------------------+--------------------+
# only showing top 20 rows
#
# associatiobn rules for frequent itemsets with minSupport=0.03 and minConfidence=0.07
#
# +--------------------+--------------------+-------------------+-----------------+--------------------+
# |          antecedent|          consequent|         confidence|             lift|             support|
# +--------------------+--------------------+-------------------+-----------------+--------------------+
# |[JUMBO STORAGE BA...|[JUMBO BAG RED RE...| 0.6120543293718166|6.423901616851581|  0.0332825555093939|
# |[GREEN REGENCY TE...|[ROSES REGENCY TE...| 0.7497435897435898|16.03326296605665|0.033744172090661495|
# |[ROSES REGENCY TE...|[GREEN REGENCY TE...|  0.721618953603159|16.03326296605665|0.033744172090661495|
# |[JUMBO BAG PINK P...|[JUMBO BAG RED RE...| 0.6763005780346821|7.098207084285523|0.037806398005816366|
# |[JUMBO BAG RED RE...|[JUMBO SHOPPER VI...|0.32751937984496127|6.084950536519208|  0.0312052808936897|
# |[JUMBO BAG RED RE...|[JUMBO BAG PINK P...|0.39680232558139533|7.098207084285522|0.037806398005816366|
# |[JUMBO BAG RED RE...|[JUMBO STORAGE BA...| 0.3493217054263566|6.423901616851581|  0.0332825555093939|
# |[JUMBO SHOPPER VI...|[JUMBO BAG RED RE...| 0.5797598627787307|6.084950536519207|  0.0312052808936897|
# +--------------------+--------------------+-------------------+-----------------+--------------------+
#
# associatiobn rules for frequent itemsets with minSupport=0.05 and minConfidence=0.07
#
# +----------+----------+----------+----+-------+
# |antecedent|consequent|confidence|lift|support|
# +----------+----------+----------+----+-------+
# +----------+----------+----------+----+-------+
#
# associatiobn rules for frequent itemsets with minSupport=0.07 and minConfidence=0.07
#
# +----------+----------+----------+----+-------+
# |antecedent|consequent|confidence|lift|support|
# +----------+----------+----------+----+-------+
# +----------+----------+----------+----+-------+
#
# associatiobn rules for frequent itemsets with minSupport=0.1 and minConfidence=0.07
#
# +----------+----------+----------+----+-------+
# |antecedent|consequent|confidence|lift|support|
# +----------+----------+----------+----+-------+
# +----------+----------+----------+----+-------+
#
# associatiobn rules for frequent itemsets with minSupport=0.01 and minConfidence=0.1
#
# +--------------------+--------------------+-------------------+------------------+--------------------+
# |          antecedent|          consequent|         confidence|              lift|             support|
# +--------------------+--------------------+-------------------+------------------+--------------------+
# |[JUMBO BAG ALPHAB...|  [JUMBO BAG APPLES]| 0.5669099756690997|12.739596268588908| 0.01075566634353506|
# |[SET OF 6 SPICE T...|[RECIPE BOX PANTR...| 0.2952029520295203|5.8939922118115184| 0.01107879795042238|
# |[SET OF 6 SPICE T...|[SET OF 3 CAKE TI...| 0.4944649446494465| 7.958093681976939|0.018556986566957485|
# |[SET OF 6 SPICE T...|[JAM MAKING SET P...|0.26691266912669126| 5.181119311193112|  0.0100170798135069|
# |[SET OF 6 SPICE T...|[JAM MAKING SET W...|0.31857318573185733| 6.337236843442815|0.011955869454830818|
# |[PICNIC BASKET WI...|    [DOTCOM POSTAGE]|                0.5|15.298728813559322| 0.01052485805290126|
# |[RED  HARMONICA I...|[BLUE HARMONICA I...|            0.48125|17.851573202054794|0.014217790703042053|
# |[LUNCH BAG APPLE ...|[LUNCH BAG SUKI D...| 0.6447688564476886|12.956983058651463|0.012232839403591376|
# |[LUNCH BAG APPLE ...|[LUNCH BAG CARS B...| 0.5352798053527981|10.243609914626912|0.010155564787887181|
# |[LUNCH BAG APPLE ...|[LUNCH BAG RED RE...| 0.6545012165450121| 9.200817556141855|0.012417486036098416|
# |[LUNCH BAG APPLE ...|[LUNCH BAG SPACEB...|  0.559610705596107| 10.56917760708672| 0.01061718136915478|
# |[ALARM CLOCK BAKE...|[ALARM CLOCK BAKE...|0.35071090047393366|18.219305124620682|0.010247888104140701|
# |[ALARM CLOCK BAKE...|[ALARM CLOCK BAKE...| 0.4834123222748815|13.797313751568852|0.014125467386788533|
# |[ALARM CLOCK BAKE...|[ALARM CLOCK BAKE...| 0.4060031595576619|15.677801150619661|0.011863546138577298|
# |[LUNCH BAG PINK P...|[LUNCH BAG WOODLAND]|0.47217537942664417|10.187983311274296|0.012925264275492775|
# |[LUNCH BAG PINK P...|[LUNCH BAG SUKI D...| 0.4924114671163575|  9.89527793334105|0.013479204173013895|
# |[LUNCH BAG PINK P...|[LUNCH BAG CARS B...| 0.5328836424957841|10.197754723839374|0.014587083968056132|
# |[LUNCH BAG PINK P...|[JUMBO BAG RED RE...| 0.3827993254637437| 4.017723734264089|  0.0104786963947745|
# |[LUNCH BAG PINK P...|[LUNCH BAG  BLACK...|  0.596964586846543|10.263526860997349| 0.01634122697687301|
# |[LUNCH BAG PINK P...|[LUNCH BAG SPACEB...| 0.4839797639123103| 9.140761661405735|0.013248395882380096|
# +--------------------+--------------------+-------------------+------------------+--------------------+
# only showing top 20 rows
#
# associatiobn rules for frequent itemsets with minSupport=0.03 and minConfidence=0.1
#
# +--------------------+--------------------+-------------------+-----------------+--------------------+
# |          antecedent|          consequent|         confidence|             lift|             support|
# +--------------------+--------------------+-------------------+-----------------+--------------------+
# |[JUMBO STORAGE BA...|[JUMBO BAG RED RE...| 0.6120543293718166|6.423901616851581|  0.0332825555093939|
# |[GREEN REGENCY TE...|[ROSES REGENCY TE...| 0.7497435897435898|16.03326296605665|0.033744172090661495|
# |[ROSES REGENCY TE...|[GREEN REGENCY TE...|  0.721618953603159|16.03326296605665|0.033744172090661495|
# |[JUMBO BAG PINK P...|[JUMBO BAG RED RE...| 0.6763005780346821|7.098207084285523|0.037806398005816366|
# |[JUMBO BAG RED RE...|[JUMBO SHOPPER VI...|0.32751937984496127|6.084950536519208|  0.0312052808936897|
# |[JUMBO BAG RED RE...|[JUMBO BAG PINK P...|0.39680232558139533|7.098207084285522|0.037806398005816366|
# |[JUMBO BAG RED RE...|[JUMBO STORAGE BA...| 0.3493217054263566|6.423901616851581|  0.0332825555093939|
# |[JUMBO SHOPPER VI...|[JUMBO BAG RED RE...| 0.5797598627787307|6.084950536519207|  0.0312052808936897|
# +--------------------+--------------------+-------------------+-----------------+--------------------+
#
# associatiobn rules for frequent itemsets with minSupport=0.05 and minConfidence=0.1
#
# +----------+----------+----------+----+-------+
# |antecedent|consequent|confidence|lift|support|
# +----------+----------+----------+----+-------+
# +----------+----------+----------+----+-------+
#
# associatiobn rules for frequent itemsets with minSupport=0.07 and minConfidence=0.1
#
# +----------+----------+----------+----+-------+
# |antecedent|consequent|confidence|lift|support|
# +----------+----------+----------+----+-------+
# +----------+----------+----------+----+-------+
#
# associatiobn rules for frequent itemsets with minSupport=0.1 and minConfidence=0.1
#
# +----------+----------+----------+----+-------+
# |antecedent|consequent|confidence|lift|support|
# +----------+----------+----------+----+-------+
# +----------+----------+----------+----+-------+

# %% [markdown]
# The best result in these associations are that even if the Support is low, it doesn't mean that it will have a bad lift, and a low confidence doesn't mean a bad lift too, but a low confidence and a low support usually result in a low lift
